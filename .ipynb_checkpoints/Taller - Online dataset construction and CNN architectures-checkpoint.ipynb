# %% [markdown]
# # Design an image classification experiment
#
# Use the code in the notebook on **Online dataset construction** to create an image classification experiment with two classes.
#
# You must:
#
# 1. Define a Google images query pair to generate your annotated dataset. Some suggestions (**WARN:** do not use blanks in your queries, use underscores instead)
#
#     - plant/tree
#     - nature/city
#     - futbol/baloncesto
#     - doritos/detodito
#     - people_with_glasses/portrait
#
#
# 2. Define 3 or 4 CNN architectures with increasing complexity. You must select a query pair so that as you increase CNN complexity classification accuracy improves. Suggestions for variations for tour experiment:
#
#     - images 64x64 or 128x128 resolution.
#     - increase the number of images.
#     - increase layers (convolutional and/or dense).
#     - add pooling if your network becomes too large or you see overfitting.
#     - increase dropout among layers if you see overfitting.
#
#
# **IN YOUR EXPERIMENT THERE MUST BE AN EVIDENCE OF ACCURACY IMPROVEMENT IN TEST DATA AS YOU INCREASE THE COMPLEXITY OF YOUR CNN ARCHITECTURE**. For this, you will need to iterate several times until you select an appropriate Google images query pair so that the visual classification task beholds the appropriate complexity.

# %%
.. COPY, PASTE AND ADJUST CODE FROM ONLINE DATASET CONSTRUCTION NOTEBOOK ...

# %% [markdown]
# ## THIS NOTEBOOK MUST BE SELF CONTAINED
#
# include all code to download and prepare images, together with your network models and training

# %%
import tensorflow as tf
from time import time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mlutils
import os
# %matplotlib inline
# Out:
# /opt/miniconda/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
# !pip install google_images_download
# Out:
# Collecting google_images_download
#   Downloading https://files.pythonhosted.org/packages/43/51/49ebfd3a02945974b1d93e34bb96a1f9530a0dde9c2bc022b30fd658edd6/google_images_download-2.5.0.tar.gz
# Collecting selenium (from google_images_download)
#   Downloading https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl (904kB)
#     100% |████████████████████████████████| 911kB 708kB/s ta 0:00:01
# Requirement already satisfied: urllib3 in /opt/miniconda/lib/python2.7/site-packages (from selenium->google_images_download)
# Building wheels for collected packages: google-images-download
#   Running setup.py bdist_wheel for google-images-download ... done
#   Stored in directory: /home/user/.cache/pip/wheels/d2/23/84/3cec6d566b88bef64ad727a7e805f6544b8af4a8f121f9691c
# Successfully built google-images-download
# Installing collected packages: selenium, google-images-download
# Successfully installed google-images-download-2.5.0 selenium-3.141.0
# You are using pip version 9.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
downloads = 'tmp/downloads'
traintest_imgs = "tmp/imgs"
train_pct = .7

# %%
# !rm -rf $downloads

# %%
# !mkdir $downloads

# %%
cfg="""
{
    "Records": [
        {
            "keywords": "sleeping_yellow_cat",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium",
            "output_directory": "%s"
        },
        {
            "keywords": "panzerotti",
            "format": "jpg",
            "limit": 50,
            "type": "photo",
            "size": "medium", 
            "output_directory": "%s"
        }
    ]
}
"""%(downloads, downloads)

# %%
with open(downloads+"/cfg.txt", "w") as f:
    f.write(cfg)

# %%
# !googleimagesdownload --config_file $downloads/cfg.txt
# Out:
# Item no.: 1 --> Item name = sleeping_yellow_cat
# Evaluating...
# Starting Download...
# Completed Image ====> 1. sleeping-yellow-cat-jeng-suntorn-niamwhan.jpg
# Completed Image ====> 2. yellow-cat-are-sleeping-picture_csp49541610.jpg
# Completed Image ====> 33. panzerotti-receta-italiana.jpg
# Completed Image ====> 34. 69214278-panzerotti-llena-de-queso-salami-y-el-puerro-estofado-panzerotti-son-creadas-por-una-t%c3%adpica-receta-ita.jpg
# Completed Image ====> 35. panzarotto-906x676.jpg
# Completed Image ====> 36. tomate-puglia-panzerotti-mozzarella-almacen-de-fotografias_csp57207401.jpg
# Completed Image ====> 37. cravings-of-a-lunatic-panzerotti-23.jpg
# Completed Image ====> 38. panzerotti.jpeg
# Completed Image ====> 39. fotolia_105481756_subscription_monthly_m-1024x680.jpg
# Completed Image ====> 40. mmmmmmmm-410x427.jpg
# Completed Image ====> 41. 83a7830f90485cffb572e1ee10896b87.jpg
# Completed Image ====> 42. making_panzerotti_in_bari_elizabeth_minchilli_in_rome-3.jpg
# Completed Image ====> 43. panzerotti-speck-e-provola-canuti-3-kg--cj-.jpg
# Completed Image ====> 44. puglia-panzerotti-italia-almacen-de-fotografias_csp51318507.jpg
# Completed Image ====> 45. panzerotti-radicchio-speck-250gr.jpg
# Completed Image ====> 46. anteprima_panzerotti-mozzarella_1200.jpg
# Completed Image ====> 47. pizza-builder-pan.jpg
# Completed Image ====> 48. unnamed1.jpg
# Completed Image ====> 49. panzerotti-pasta-with-porchini-mushroom-filling-.jpg
# Completed Image ====> 50. bpudcmuga4frkimetodos2woqku8ux2zgug.jpg
#
# Errors: 0
#
#
# Everything downloaded!
# Total time taken: 53.7036390305 Seconds

# %%
from skimage import io
files = !find $downloads -type f
for fname in files:
    if fname!=downloads+"/cfg.txt":
        print (".")
        try:
            io.imread(fname)
        except:
            print ("\nremoving",fname,"as cannot be read\n")
            # !rm '$fname'
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ('\nremoving', 'tmp/downloads/sleeping_yellow_cat/14. new-simulation-breathing-cat-model-polyethylene-fur-yellow-sleeping-cat-doll-gift-about-23x19cm-2390.jpg', 'as cannot be read\n')
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ('\nremoving', 'tmp/downloads/sleeping_yellow_cat/40. cute-simulation-yellow-cat-lovely-sleeping-cat-doll-gift-about-18x13cm.jpg', 'as cannot be read\n')
# .
# .
# .
# ('\nremoving', 'tmp/downloads/sleeping_yellow_cat/36. simulation-sleeping-cat-lifelike-handicraft-yellow-cat-doll-gift-about-29x10x31cm.jpg', 'as cannot be read\n')
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ('\nremoving', 'tmp/downloads/sleeping_yellow_cat/41. new-simulation-sleeping-cat-lifelike-creative-yellow-cat-gift-25x20x11cm.jpg', 'as cannot be read\n')
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
classdirs = !find $downloads -type d
classdirs = [i.split("/")[-1] for i in classdirs if i!=downloads]
print classdirs
# Out:
# ['sleeping_yellow_cat', 'panzerotti']

# %%
# !rm -rf $traintest_imgs

# %%
for classdir in classdirs:
    print (classdir)
    print ("    splitting files ... "),
    files = !find $downloads/$classdir -type f
    files = np.r_[files]
    n_train = int(len(files)*train_pct)
    files = np.random.permutation(files)
    files_train = files[:n_train]
    files_test  = files[n_train:]
    # !mkdir -p $traintest_imgs/train/$classdir
    # !mkdir -p $traintest_imgs/test/$classdir
    print ("copying files")
    for f in files_train:
        # !cp '$f' $traintest_imgs/train/$classdir
    for f in files_test:
        # !cp '$f' $traintest_imgs/test/$classdir
# Out:
# sleeping_yellow_cat
#     splitting files ...  copying files
# panzerotti
#     splitting files ...  copying files

# %%
for classdir in classdirs:
    print (classdir)
    files = !find  $traintest_imgs/train/$classdir -type f
    print ("      ",len(files), "train images")
    files = !find  $traintest_imgs/test/$classdir -type f
    print ("      ",len(files), "test images")
# Out:
# sleeping_yellow_cat
# ('      ', 32, 'train images')
# ('      ', 14, 'test images')
# panzerotti
# ('      ', 35, 'train images')
# ('      ', 15, 'test images')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
datagen = ImageDataGenerator(rescale=1./255, fill_mode='nearest')
batch_size = 10
img_size = 32
train_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/train",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary') 

test_generator_fn = lambda: datagen.flow_from_directory(
        traintest_imgs+"/test",  # this is the target directory
        target_size=(img_size, img_size),  # all images will be resized to 150x150
        batch_size=batch_size,
        interpolation = "bilinear",
        class_mode='binary')

# %%
for imgs,labels in train_generator_fn():
    if np.random.random()>.5:
        break
reload(mlutils)        
mlutils.show_labeled_image_mosaic(imgs, labels)
# Out:
# Found 67 images belonging to 2 classes.

# %% [markdown]
# ## Definimos una red de una sola capa convolucional

# %%
def get_conv_model_A(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print ("using",num_classes,"classes")
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(15,(10,10), activation="relu")(inputs)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(64, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
num_classes = len(classdirs)
model = get_conv_model_A(num_classes, img_size=img_size)

model.fit_generator(
        train_generator_fn(),
        steps_per_epoch=1000 // batch_size,
        epochs=3,
        validation_data=test_generator_fn(),
        validation_steps=400 // batch_size)
# Out:
# ('using', 2, 'classes')
# Found 67 images belonging to 2 classes.
# Found 29 images belonging to 2 classes.
# Epoch 1/5
# 100/100 [==============================] - 16s 156ms/step - loss: 0.5830 - acc: 0.7303 - val_loss: 0.5732 - val_acc: 0.6899
# Epoch 2/5
# 100/100 [==============================] - 14s 141ms/step - loss: 0.3385 - acc: 0.8670 - val_loss: 0.8188 - val_acc: 0.6202
# Epoch 3/5
# 100/100 [==============================] - 15s 149ms/step - loss: 0.1736 - acc: 0.9404 - val_loss: 1.1827 - val_acc: 0.6873
# Epoch 4/5
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0878 - acc: 0.9694 - val_loss: 1.3408 - val_acc: 0.6615
# Epoch 5/5
# 100/100 [==============================] - 15s 149ms/step - loss: 0.0564 - acc: 0.9856 - val_loss: 1.7129 - val_acc: 0.6563

# %%
def show_preds(x, preds):
    for i  in np.random.permutation(range(len(preds)))[:4]:
        plt.figure(figsize=(5,2.5))
        plt.subplot(122)
        plt.imshow(x[i])
        plt.axis("off")
        plt.subplot(121)
        plt.bar(np.arange(2), preds[i], color="blue", alpha=.5, label="prediction")
        plt.bar(np.arange(2), np.eye(2,2)[int(y[i])], color="red", alpha=.5, label="label")
        plt.xticks(range(2), range(2), rotation="vertical");
        plt.xlim(-.5,1.5);
        plt.legend(loc='upper center', bbox_to_anchor=(0.5, +1.35),ncol=5)

# %%
for x,y in test_generator_fn():
    if np.random.random()>.7:
        break
        
preds = model.predict(x)
mlutils.show_preds(x, y, preds)
# Out:
# Found 29 images belonging to 2 classes.

# %% [markdown]
# ### Activaciones de los pesos (filtro) de la primera capa

# %%
w0 = model.get_weights()[0]
print w0.shape
mlutils.display_imgs(w0,figsize=(10,10))
# Out:
# (10, 10, 3, 15)

# %% [markdown]
# ### 2. Definimos una segunda arquitectura con mas capas.

# %%
def get_conv_model_B(num_classes, img_size=32, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print ("using",num_classes,"classes")
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(25,(10,10), activation="relu")(inputs)
    layers=tf.keras.layers.Conv2D(15,(10,10),activation='relu')(layers)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(64, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])
    return model

# %%
num_classes = len(classdirs)
model = get_conv_model_B(num_classes, img_size=img_size)

model.fit_generator(
        train_generator_fn(),
        steps_per_epoch=1000 // batch_size,
        epochs=3,
        validation_data=test_generator_fn(),
        validation_steps=400 // batch_size)
# Out:
# ('using', 2, 'classes')
# Found 67 images belonging to 2 classes.
# Found 29 images belonging to 2 classes.
# Epoch 1/3
# 100/100 [==============================] - 18s 177ms/step - loss: 0.6992 - acc: 0.5168 - val_loss: 0.6924 - val_acc: 0.5194
# Epoch 2/3
# 100/100 [==============================] - 16s 162ms/step - loss: 0.6924 - acc: 0.5213 - val_loss: 0.6928 - val_acc: 0.5142
# Epoch 3/3
# 100/100 [==============================] - 16s 161ms/step - loss: 0.6924 - acc: 0.5203 - val_loss: 0.6932 - val_acc: 0.5090

# %%
for x,y in test_generator_fn():
    if np.random.random()>.7:
        break
        
preds = model.predict(x)
mlutils.show_preds(x, y, preds)
# Out:
# Found 29 images belonging to 2 classes.

# %% [markdown]
# ### Activaciones de los pesos (filtro) de la primera capa

# %%
w0 = model.get_weights()[0]
print w0.shape
mlutils.display_imgs(w0,figsize=(10,10))
# Out:
# (10, 10, 3, 25)

# %%
model.get_weights()[3]
# Out:
# array([-0.00357552, -0.00600524, -0.00741284, -0.00343744, -0.00600183,
#        -0.00600538, -0.00387016, -0.00485879, -0.00723265, -0.00343015,
#        -0.00600544, -0.00600528, -0.00600538, -0.00618646, -0.00542112],
#       dtype=float32)

# %%
w0 = model.get_weights()[0]
print w0.shape
mlutils.display_imgs(w0,figsize=(10,10))
# Out:
# (10, 10, 3, 25)
